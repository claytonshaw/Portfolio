# %%
import pandas as pd
from pycaret.classification import *

session_id = 1234

# %%
df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %% [markdown]
# Based on the number of unique variables the following data types should change
# 1. Pclass - ordinal
# 2. Sex - categorical
# 3. Embarked - categorical
#
# PassengerId, Cabin, Name, and Ticket will be dropped because they are unique identifiers or missing to much data.
#
# We can create new feature variables from some of our existing columns such as total family size and the fare per person

# %% [markdown]
# ### Updating Train Data

# %%
# imputing mean for age and mode for embarked
most_common_embarked = df['Embarked'].mode()[0] 
df = df.fillna({'Age':df['Age'].mean(), 'Embarked':most_common_embarked})

# adding feature variables
df['Family_Size'] = df['SibSp'] + df['Parch'] + 1
df['Fare_Per_Person'] = df['Fare'] / df['Family_Size']

# %% [markdown]
# ### Updating Test Data

# %%
# imputing mean for age and mode for embarked
test_df = test_df.fillna({'Age':test_df['Age'].mean(), 'Embarked':most_common_embarked})

# adding feature variables
test_df['Family_Size'] = test_df['SibSp'] + test_df['Parch'] + 1
test_df['Fare_Per_Person'] = test_df['Fare'] / test_df['Family_Size']

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex        Age  \
# 0                            Braund, Mr. Owen Harris    male  22.000000
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                             Heikkinen, Miss. Laina  female  26.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                           Allen, Mr. William Henry    male  35.000000
# 5                                   Moran, Mr. James    male  29.699118
# 6                            McCarthy, Mr. Timothy J    male  54.000000
# 7                     Palsson, Master. Gosta Leonard    male   2.000000
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.000000
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.000000
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked  Family_Size  \
# 0      1      0         A/5 21171   7.2500   NaN        S            2
# 1      1      0          PC 17599  71.2833   C85        C            2
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S            1
# 3      1      0            113803  53.1000  C123        S            2
# 4      0      0            373450   8.0500   NaN        S            1
# 5      0      0            330877   8.4583   NaN        Q            1
# 6      0      0             17463  51.8625   E46        S            1
# 7      3      1            349909  21.0750   NaN        S            5
# 8      0      2            347742  11.1333   NaN        S            3
# 9      1      0            237736  30.0708   NaN        C            2
#
#    Fare_Per_Person
# 0          3.62500
# 1         35.64165
# 2          7.92500
# 3         26.55000
# 4          8.05000
# 5          8.45830
# 6         51.86250
# 7          4.21500
# 8          3.71110
# 9         15.03540

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PassengerId      891 non-null    int64
#  1   Survived         891 non-null    int64
#  2   Pclass           891 non-null    int64
#  3   Name             891 non-null    object
#  4   Sex              891 non-null    object
#  5   Age              891 non-null    float64
#  6   SibSp            891 non-null    int64
#  7   Parch            891 non-null    int64
#  8   Ticket           891 non-null    object
#  9   Fare             891 non-null    float64
#  10  Cabin            204 non-null    object
#  11  Embarked         891 non-null    object
#  12  Family_Size      891 non-null    int64
#  13  Fare_Per_Person  891 non-null    float64
# dtypes: float64(3), int64(6), object(5)
# memory usage: 97.6+ KB

# %% [markdown]
# ## Pycaret Set up

# %%
models = setup(data=df,
               target='Survived', train_size=0.8,
               ignore_features=['PassengerId', 'Name', 'Ticket', 'Cabin'],
               numeric_features=['SibSp', 'Parch', 'Fare','Family_Size','Fare_Per_Person'],
               categorical_features=['Sex', 'Embarked'],
               ordinal_features={'Pclass':['1','2','3']},
               normalize=True,
               session_id=session_id
               )
# Out:
# <style type="text/css">
# #T_64857_row12_col1, #T_64857_row18_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_64857">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64857_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_64857_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64857_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_64857_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_64857_row0_col1" class="data row0 col1" >1234</td>
#     </tr>
#     <tr>
#       <th id="T_64857_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_64857_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_64857_row1_col1" class="data row1 col1" >Survived</td>
#     </tr>
#     <tr>
#       <th id="T_64857_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_64857_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_64857_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_64857_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_64857_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_64857_row3_col1" class="data row3 col1" >(891, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_64857_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_64857_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_64857_row4_col1" class="data row4 col1" >(891, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_64857_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_64857_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_64857_row5_col1" class="data row5 col1" >(712, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_64857_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_64857_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_64857_row6_col1" class="data row6 col1" >(179, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_64857_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_64857_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_64857_row7_col1" class="data row7 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_64857_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_64857_row8_col0" class="data row8 col0" >Ordinal features</td>
#       <td id="T_64857_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_64857_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_64857_row9_col0" class="data row9 col0" >Numeric features</td>
#       <td id="T_64857_row9_col1" class="data row9 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_64857_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_64857_row10_col0" class="data row10 col0" >Categorical features</td>
#       <td id="T_64857_row10_col1" class="data row10 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_64857_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_64857_row11_col0" class="data row11 col0" >Rows with missing values</td>
#       <td id="T_64857_row11_col1" class="data row11 col1" >77.1%</td>
#     </tr>
#     <tr>
#       <th id="T_64857_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_64857_row12_col0" class="data row12 col0" >Preprocess</td>
#       <td id="T_64857_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_64857_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_64857_row13_col0" class="data row13 col0" >Imputation type</td>
#       <td id="T_64857_row13_col1" class="data row13 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_64857_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_64857_row14_col0" class="data row14 col0" >Numeric imputation</td>
#       <td id="T_64857_row14_col1" class="data row14 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_64857_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_64857_row15_col0" class="data row15 col0" >Categorical imputation</td>
#       <td id="T_64857_row15_col1" class="data row15 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_64857_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_64857_row16_col0" class="data row16 col0" >Maximum one-hot encoding</td>
#       <td id="T_64857_row16_col1" class="data row16 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_64857_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_64857_row17_col0" class="data row17 col0" >Encoding method</td>
#       <td id="T_64857_row17_col1" class="data row17 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_64857_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_64857_row18_col0" class="data row18 col0" >Normalize</td>
#       <td id="T_64857_row18_col1" class="data row18 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_64857_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_64857_row19_col0" class="data row19 col0" >Normalize method</td>
#       <td id="T_64857_row19_col1" class="data row19 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_64857_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_64857_row20_col0" class="data row20 col0" >Fold Generator</td>
#       <td id="T_64857_row20_col1" class="data row20 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_64857_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_64857_row21_col0" class="data row21 col0" >Fold Number</td>
#       <td id="T_64857_row21_col1" class="data row21 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_64857_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_64857_row22_col0" class="data row22 col0" >CPU Jobs</td>
#       <td id="T_64857_row22_col1" class="data row22 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_64857_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_64857_row23_col0" class="data row23 col0" >Use GPU</td>
#       <td id="T_64857_row23_col1" class="data row23 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_64857_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_64857_row24_col0" class="data row24 col0" >Log Experiment</td>
#       <td id="T_64857_row24_col1" class="data row24 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_64857_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_64857_row25_col0" class="data row25 col0" >Experiment Name</td>
#       <td id="T_64857_row25_col1" class="data row25 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_64857_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_64857_row26_col0" class="data row26 col0" >USI</td>
#       <td id="T_64857_row26_col1" class="data row26 col1" >8360</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_1317e th {
#   text-align: left;
# }
# #T_1317e_row0_col0, #T_1317e_row0_col2, #T_1317e_row0_col3, #T_1317e_row1_col0, #T_1317e_row1_col1, #T_1317e_row1_col3, #T_1317e_row1_col4, #T_1317e_row1_col5, #T_1317e_row1_col6, #T_1317e_row1_col7, #T_1317e_row2_col0, #T_1317e_row2_col1, #T_1317e_row2_col2, #T_1317e_row2_col4, #T_1317e_row2_col5, #T_1317e_row2_col6, #T_1317e_row2_col7, #T_1317e_row3_col0, #T_1317e_row3_col1, #T_1317e_row3_col2, #T_1317e_row3_col3, #T_1317e_row3_col4, #T_1317e_row3_col5, #T_1317e_row3_col6, #T_1317e_row3_col7, #T_1317e_row4_col0, #T_1317e_row4_col1, #T_1317e_row4_col2, #T_1317e_row4_col3, #T_1317e_row4_col4, #T_1317e_row4_col5, #T_1317e_row4_col6, #T_1317e_row4_col7, #T_1317e_row5_col0, #T_1317e_row5_col1, #T_1317e_row5_col2, #T_1317e_row5_col3, #T_1317e_row5_col4, #T_1317e_row5_col5, #T_1317e_row5_col6, #T_1317e_row5_col7, #T_1317e_row6_col0, #T_1317e_row6_col1, #T_1317e_row6_col2, #T_1317e_row6_col3, #T_1317e_row6_col4, #T_1317e_row6_col5, #T_1317e_row6_col6, #T_1317e_row6_col7, #T_1317e_row7_col0, #T_1317e_row7_col1, #T_1317e_row7_col2, #T_1317e_row7_col3, #T_1317e_row7_col4, #T_1317e_row7_col5, #T_1317e_row7_col6, #T_1317e_row7_col7, #T_1317e_row8_col0, #T_1317e_row8_col1, #T_1317e_row8_col2, #T_1317e_row8_col3, #T_1317e_row8_col4, #T_1317e_row8_col5, #T_1317e_row8_col6, #T_1317e_row8_col7, #T_1317e_row9_col0, #T_1317e_row9_col1, #T_1317e_row9_col2, #T_1317e_row9_col3, #T_1317e_row9_col4, #T_1317e_row9_col5, #T_1317e_row9_col6, #T_1317e_row9_col7, #T_1317e_row10_col0, #T_1317e_row10_col1, #T_1317e_row10_col2, #T_1317e_row10_col3, #T_1317e_row10_col4, #T_1317e_row10_col5, #T_1317e_row10_col6, #T_1317e_row10_col7, #T_1317e_row11_col0, #T_1317e_row11_col1, #T_1317e_row11_col2, #T_1317e_row11_col3, #T_1317e_row11_col4, #T_1317e_row11_col5, #T_1317e_row11_col6, #T_1317e_row11_col7, #T_1317e_row12_col0, #T_1317e_row12_col1, #T_1317e_row12_col2, #T_1317e_row12_col3, #T_1317e_row12_col4, #T_1317e_row12_col5, #T_1317e_row12_col6, #T_1317e_row12_col7, #T_1317e_row13_col0, #T_1317e_row13_col1, #T_1317e_row13_col2, #T_1317e_row13_col3, #T_1317e_row13_col4, #T_1317e_row13_col5, #T_1317e_row13_col6, #T_1317e_row13_col7, #T_1317e_row14_col0, #T_1317e_row14_col1, #T_1317e_row14_col2, #T_1317e_row14_col3, #T_1317e_row14_col4, #T_1317e_row14_col5, #T_1317e_row14_col6, #T_1317e_row14_col7 {
#   text-align: left;
# }
# #T_1317e_row0_col1, #T_1317e_row0_col4, #T_1317e_row0_col5, #T_1317e_row0_col6, #T_1317e_row0_col7, #T_1317e_row1_col2, #T_1317e_row2_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_1317e_row0_col8, #T_1317e_row1_col8, #T_1317e_row2_col8, #T_1317e_row3_col8, #T_1317e_row4_col8, #T_1317e_row5_col8, #T_1317e_row6_col8, #T_1317e_row7_col8, #T_1317e_row11_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_1317e_row8_col8, #T_1317e_row9_col8, #T_1317e_row10_col8, #T_1317e_row12_col8, #T_1317e_row13_col8, #T_1317e_row14_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_1317e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1317e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1317e_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_1317e_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_1317e_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_1317e_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_1317e_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_1317e_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_1317e_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_1317e_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1317e_level0_row0" class="row_heading level0 row0" >gbc</th>
#       <td id="T_1317e_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_1317e_row0_col1" class="data row0 col1" >0.8245</td>
#       <td id="T_1317e_row0_col2" class="data row0 col2" >0.8848</td>
#       <td id="T_1317e_row0_col3" class="data row0 col3" >0.7402</td>
#       <td id="T_1317e_row0_col4" class="data row0 col4" >0.7902</td>
#       <td id="T_1317e_row0_col5" class="data row0 col5" >0.7621</td>
#       <td id="T_1317e_row0_col6" class="data row0 col6" >0.6237</td>
#       <td id="T_1317e_row0_col7" class="data row0 col7" >0.6266</td>
#       <td id="T_1317e_row0_col8" class="data row0 col8" >0.0190</td>
#     </tr>
#     <tr>
#       <th id="T_1317e_level0_row1" class="row_heading level0 row1" >catboost</th>
#       <td id="T_1317e_row1_col0" class="data row1 col0" >CatBoost Classifier</td>
#       <td id="T_1317e_row1_col1" class="data row1 col1" >0.8231</td>
#       <td id="T_1317e_row1_col2" class="data row1 col2" >0.8904</td>
#       <td id="T_1317e_row1_col3" class="data row1 col3" >0.7401</td>
#       <td id="T_1317e_row1_col4" class="data row1 col4" >0.7868</td>
#       <td id="T_1317e_row1_col5" class="data row1 col5" >0.7608</td>
#       <td id="T_1317e_row1_col6" class="data row1 col6" >0.6210</td>
#       <td id="T_1317e_row1_col7" class="data row1 col7" >0.6235</td>
#       <td id="T_1317e_row1_col8" class="data row1 col8" >0.3390</td>
#     </tr>
#     <tr>
#       <th id="T_1317e_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_1317e_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_1317e_row2_col1" class="data row2 col1" >0.8174</td>
#       <td id="T_1317e_row2_col2" class="data row2 col2" >0.8703</td>
#       <td id="T_1317e_row2_col3" class="data row2 col3" >0.7581</td>
#       <td id="T_1317e_row2_col4" class="data row2 col4" >0.7624</td>
#       <td id="T_1317e_row2_col5" class="data row2 col5" >0.7588</td>
#       <td id="T_1317e_row2_col6" class="data row2 col6" >0.6122</td>
#       <td id="T_1317e_row2_col7" class="data row2 col7" >0.6136</td>
#       <td id="T_1317e_row2_col8" class="data row2 col8" >0.0660</td>
#     </tr>
#     <tr>
#       <th id="T_1317e_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_1317e_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_1317e_row3_col1" class="data row3 col1" >0.8005</td>
#       <td id="T_1317e_row3_col2" class="data row3 col2" >0.8742</td>
#       <td id="T_1317e_row3_col3" class="data row3 col3" >0.7358</td>
#       <td id="T_1317e_row3_col4" class="data row3 col4" >0.7450</td>
#       <td id="T_1317e_row3_col5" class="data row3 col5" >0.7378</td>
#       <td id="T_1317e_row3_col6" class="data row3 col6" >0.5772</td>
#       <td id="T_1317e_row3_col7" class="data row3 col7" >0.5798</td>
#       <td id="T_1317e_row3_col8" class="data row3 col8" >0.0340</td>
#     </tr>
#     <tr>
#       <th id="T_1317e_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_1317e_row4_col0" class="data row4 col0" >Ada Boost Classifier</td>
#       <td id="T_1317e_row4_col1" class="data row4 col1" >0.7964</td>
#       <td id="T_1317e_row4_col2" class="data row4 col2" >0.8490</td>
#       <td id="T_1317e_row4_col3" class="data row4 col3" >0.7507</td>
#       <td id="T_1317e_row4_col4" class="data row4 col4" >0.7282</td>
#       <td id="T_1317e_row4_col5" class="data row4 col5" >0.7383</td>
#       <td id="T_1317e_row4_col6" class="data row4 col6" >0.5718</td>
#       <td id="T_1317e_row4_col7" class="data row4 col7" >0.5730</td>
#       <td id="T_1317e_row4_col8" class="data row4 col8" >0.0180</td>
#     </tr>
#     <tr>
#       <th id="T_1317e_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_1317e_row5_col0" class="data row5 col0" >K Neighbors Classifier</td>
#       <td id="T_1317e_row5_col1" class="data row5 col1" >0.7949</td>
#       <td id="T_1317e_row5_col2" class="data row5 col2" >0.8420</td>
#       <td id="T_1317e_row5_col3" class="data row5 col3" >0.7033</td>
#       <td id="T_1317e_row5_col4" class="data row5 col4" >0.7491</td>
#       <td id="T_1

# %%
tune = tune_model(best)
# Out:
# <style type="text/css">
# #T_faca6_row10_col0, #T_faca6_row10_col1, #T_faca6_row10_col2, #T_faca6_row10_col3, #T_faca6_row10_col4, #T_faca6_row10_col5, #T_faca6_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_faca6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_faca6_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_faca6_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_faca6_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_faca6_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_faca6_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_faca6_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_faca6_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_faca6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_faca6_row0_col0" class="data row0 col0" >0.7917</td>
#       <td id="T_faca6_row0_col1" class="data row0 col1" >0.8255</td>
#       <td id="T_faca6_row0_col2" class="data row0 col2" >0.6429</td>
#       <td id="T_faca6_row0_col3" class="data row0 col3" >0.7826</td>
#       <td id="T_faca6_row0_col4" class="data row0 col4" >0.7059</td>
#       <td id="T_faca6_row0_col5" class="data row0 col5" >0.5470</td>
#       <td id="T_faca6_row0_col6" class="data row0 col6" >0.5533</td>
#     </tr>
#     <tr>
#       <th id="T_faca6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_faca6_row1_col0" class="data row1 col0" >0.8194</td>
#       <td id="T_faca6_row1_col1" class="data row1 col1" >0.8933</td>
#       <td id="T_faca6_row1_col2" class="data row1 col2" >0.7143</td>
#       <td id="T_faca6_row1_col3" class="data row1 col3" >0.8000</td>
#       <td id="T_faca6_row1_col4" class="data row1 col4" >0.7547</td>
#       <td id="T_faca6_row1_col5" class="data row1 col5" >0.6126</td>
#       <td id="T_faca6_row1_col6" class="data row1 col6" >0.6150</td>
#     </tr>
#     <tr>
#       <th id="T_faca6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_faca6_row2_col0" class="data row2 col0" >0.7887</td>
#       <td id="T_faca6_row2_col1" class="data row2 col1" >0.8157</td>
#       <td id="T_faca6_row2_col2" class="data row2 col2" >0.6667</td>
#       <td id="T_faca6_row2_col3" class="data row2 col3" >0.7500</td>
#       <td id="T_faca6_row2_col4" class="data row2 col4" >0.7059</td>
#       <td id="T_faca6_row2_col5" class="data row2 col5" >0.5419</td>
#       <td id="T_faca6_row2_col6" class="data row2 col6" >0.5442</td>
#     </tr>
#     <tr>
#       <th id="T_faca6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_faca6_row3_col0" class="data row3 col0" >0.8873</td>
#       <td id="T_faca6_row3_col1" class="data row3 col1" >0.9082</td>
#       <td id="T_faca6_row3_col2" class="data row3 col2" >0.8519</td>
#       <td id="T_faca6_row3_col3" class="data row3 col3" >0.8519</td>
#       <td id="T_faca6_row3_col4" class="data row3 col4" >0.8519</td>
#       <td id="T_faca6_row3_col5" class="data row3 col5" >0.7609</td>
#       <td id="T_faca6_row3_col6" class="data row3 col6" >0.7609</td>
#     </tr>
#     <tr>
#       <th id="T_faca6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_faca6_row4_col0" class="data row4 col0" >0.7746</td>
#       <td id="T_faca6_row4_col1" class="data row4 col1" >0.8035</td>
#       <td id="T_faca6_row4_col2" class="data row4 col2" >0.6667</td>
#       <td id="T_faca6_row4_col3" class="data row4 col3" >0.7200</td>
#       <td id="T_faca6_row4_col4" class="data row4 col4" >0.6923</td>
#       <td id="T_faca6_row4_col5" class="data row4 col5" >0.5149</td>
#       <td id="T_faca6_row4_col6" class="data row4 col6" >0.5159</td>
#     </tr>
#     <tr>
#       <th id="T_faca6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_faca6_row5_col0" class="data row5 col0" >0.8451</td>
#       <td id="T_faca6_row5_col1" class="data row5 col1" >0.8822</td>
#       <td id="T_faca6_row5_col2" class="data row5 col2" >0.8519</td>
#       <td id="T_faca6_row5_col3" class="data row5 col3" >0.7667</td>
#       <td id="T_faca6_row5_col4" class="data row5 col4" >0.8070</td>
#       <td id="T_faca6_row5_col5" class="data row5 col5" >0.6782</td>
#       <td id="T_faca6_row5_col6" class="data row5 col6" >0.6808</td>
#     </tr>
#     <tr>
#       <th id="T_faca6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_faca6_row6_col0" class="data row6 col0" >0.8592</td>
#       <td id="T_faca6_row6_col1" class="data row6 col1" >0.9276</td>
#       <td id="T_faca6_row6_col2" class="data row6 col2" >0.7778</td>
#       <td id="T_faca6_row6_col3" class="data row6 col3" >0.8400</td>
#       <td id="T_faca6_row6_col4" class="data row6 col4" >0.8077</td>
#       <td id="T_faca6_row6_col5" class="data row6 col5" >0.6968</td>
#       <td id="T_faca6_row6_col6" class="data row6 col6" >0.6981</td>
#     </tr>
#     <tr>
#       <th id="T_faca6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_faca6_row7_col0" class="data row7 col0" >0.7887</td>
#       <td id="T_faca6_row7_col1" class="data row7 col1" >0.8552</td>
#       <td id="T_faca6_row7_col2" class="data row7 col2" >0.7037</td>
#       <td id="T_faca6_row7_col3" class="data row7 col3" >0.7308</td>
#       <td id="T_faca6_row7_col4" class="data row7 col4" >0.7170</td>
#       <td id="T_faca6_row7_col5" class="data row7 col5" >0.5485</td>
#       <td id="T_faca6_row7_col6" class="data row7 col6" >0.5488</td>
#     </tr>
#     <tr>
#       <th id="T_faca6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_faca6_row8_col0" class="data row8 col0" >0.7746</td>
#       <td id="T_faca6_row8_col1" class="data row8 col1" >0.8872</td>
#       <td id="T_faca6_row8_col2" class="data row8 col2" >0.7407</td>
#       <td id="T_faca6_row8_col3" class="data row8 col3" >0.6897</td>
#       <td id="T_faca6_row8_col4" class="data row8 col4" >0.7143</td>
#       <td id="T_faca6_row8_col5" class="data row8 col5" >0.5286</td>
#       <td id="T_faca6_row8_col6" class="data row8 col6" >0.5296</td>
#     </tr>
#     <tr>
#       <th id="T_faca6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_faca6_row9_col0" class="data row9 col0" >0.8592</td>
#       <td id="T_faca6_row9_col1" class="data row9 col1" >0.9352</td>
#       <td id="T_faca6_row9_col2" class="data row9 col2" >0.7857</td>
#       <td id="T_faca6_row9_col3" class="data row9 col3" >0.8462</td>
#       <td id="T_faca6_row9_col4" class="data row9 col4" >0.8148</td>
#       <td id="T_faca6_row9_col5" class="data row9 col5" >0.7014</td>
#       <td id="T_faca6_row9_col6" class="data row9 col6" >0.7027</td>
#     </tr>
#     <tr>
#       <th id="T_faca6_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_faca6_row10_col0" class="data row10 col0" >0.8189</td>
#       <td id="T_faca6_row10_col1" class="data row10 col1" >0.8734</td>
#       <td id="T_faca6_row10_col2" class="data row10 col2" >0.7402</td>
#       <td id="T_faca6_row10_col3" class="data row10 col3" >0.7778</td>
#       <td id="T_faca6_row10_col4" class="data row10 col4" >0.7571</td>
#       <td id="T_faca6_row10_col5" class="data row10 col5" >0.6131</td>
#       <td id="T_faca6_row10_col6" class="data row10 col6" >0.6149</td>
#     </tr>
#     <tr>
#       <th id="T_faca6_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_faca6_row11_col0" class="data row11 col0" >0.0388</td>
#       <td id="T_faca6_row11_col1" class="data row11 col1" >0.0441</td>
#       <td id="T_faca6_row11_col2" class="data row11 col2" >0.0712</td>
#       <td id="T_faca6_row11_col3" class="data row11 col3" >0.0536</td>
#       <td id="T_faca6_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
out = predict_model(tune, test_df)
out.rename(columns={'prediction_label': 'Survived'}, inplace=True)
out[['PassengerId','Survived']].to_csv('submission.csv', index=False)
